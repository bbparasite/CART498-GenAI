# %% [markdown]
# # CART 498 C - Assignment 1

# %% [markdown]
# ## Surrealistic Collage
#
# Characteristics of symbolic pairings are:
# - Juxtaposition: The elements are placed together in a way that contrasts or highlights their differences or unexpected connections.
# - Surreal logic: The pairing often challenges logic or reality, evoking dreamlike or thought-provoking ideas.
# - Metaphorical meaning: The objects represent ideas beyond their literal forms.
# - Emotional impact: The pairing is designed to provoke feelings or reflections.
#
# ## Assignment and deliverables
#
# For this assignment, you will create a series of three images that leverage the Diffusers Python library to create surreal images. Make three similar-looking images, as if they were variations, don't make three different ones. Be funny and witty!
#
# By the end of this assignment, you will submit a link to a GitHub repository named CART498-GenAI that will have a folder named A1 with:
# - Three prompts describing your images in three txt files.
# - Three generated images corresponding to those prompts, in JPG format. Make sure the txt and JPG files follow the same filename structure so that it is easy to correlate them.
# - Python code that uses the Diffusers library to create those images.
# - A short essay (250-350 words) in PDF format, summarizing your current understanding of generative AI and its applications in creative fields. Identify one work of generative AI-driven art that inspires you and explain why.

# %%
import torch

# Torch (and PyTorch) PyTorch is one of the most popular frameworks for
#  developing and training machine learning and deep learning models.

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# CUDA (Compute Unified Device Architecture) is a parallel computing platform
# and programming model developed by NVIDIA for their GPUs. CUDA harness the
# highly parallel processing power of GPUs to perform general-purpose computing
# tasks (i.e., tasks beyond traditional graphics rendering).
# Out:
# Using device: cuda

# %% [markdown]
# ## Basic image generation with Diffusers
#
# The Diffusers library is developed and maintained by Hugging Face. It comes with several diffusion models for image, video, and audio generation.
#
# You can find the source code and documentation on GitHub:
#
# https://github.com/huggingface/diffusers

# %%
from diffusers import StableDiffusionPipeline

model_id = "runwayml/stable-diffusion-v1-5"  # or any other compatible model
pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16)
pipe = pipe.to(device)  # move to GPU if available
# Out:
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# safety_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# ...

# %%
prompt = (
    "A body farm filled with both decomposing animals and humans, "
    "paper mache collaged in the style of H.R. Giger, "
    "dramatic colourful lighting, detailed scene, top down, 3D model, hyperrealistic melting textures, "
)


# Generate and save the image
image = pipe(prompt).images[0]
image

image.save("surreal_collage_5.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
